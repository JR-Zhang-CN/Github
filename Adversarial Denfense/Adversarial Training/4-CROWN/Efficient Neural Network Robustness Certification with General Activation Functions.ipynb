# %% [markdown]
# # [Efficient Neural Network Robustness Certification with General Activation Functions<br />针对通用激活函数的神经网络鲁棒性的高效认证](http://arxiv.org/abs/1811.00866)

# %% [markdown]
# This paper we introduce CROWN, a general framework to certify robustness of neural networks with general activation functions for given input data points.
# 本文我们介绍了CROWN，这是一个通用框架，用于为给定的输入数据点认证具有通用激活函数的神经网络的鲁棒性。
#
# - We propose a generic analysis framework CROWN for certifying NNs using linear or quadratic upper and lower bounds for general activation functions that are not necessarily piece-wise linear.
# 我们提出了一个通用的分析框架CROWN，用于使用线性或二次上下界来证明不一定是分段线性的通用激活函数的神经网络。
#
# - Unlike previous work, CROWN allows flexible selections of upper/lower bounds for activation functions, enabling an adaptive scheme that helps to reduce approximation errors. Our experiments show that CROWN achieves up to 26% improvements in certified lower bounds.
# 与以前的工作不同，CROWN允许灵活选择激活函数的上/下界，从而实现自适应方案，有助于减少近似误差。我们的实验表明，CROWN在认证下界方面的性能提高了26%。
#
# - Our algorithm is efficient and can scale to large NNs with various activation functions. For a NN with over 10,000 neurons, we can give a certified lower bound in about 1 minute on 1 CPU core.
# 我们的算法高效，可以扩展到具有各种激活函数的大型神经网络。对于一个具有超过10,000个神经元的神经网络，我们可以在1个CPU核心上在大约1分钟内给出一个认证的下界。

# %% [markdown]
# # CROWN: A general framework for certifying neural networks<br />CROWN：认证神经网络的通用框架
#
# $$
# Φ_{k}(x) = σ(W^{(k)}Φ_{k−1}(x) + b^{(k)}) \\
# y^{(k)}_{r} = W^{(k)}_{r,:} Φ_{k−1}(x) + b^{(k)}_{r} \\
# f (x) = Φ_{m}(x) \\
# l^{(k)}_{r}  ≤ y^{(k)}_{r}  ≤ u^{(k)}_{r}
# $$
#
# ![1696421041490.png](attachment:1696421041490.png)
#
# ![2.png](attachment:2.png)
#
# ![3.png](attachment:3.png)
#
# ![4.png](attachment:4.png)
#
# Fortunately, we can still perform a binary search to obtain $\widetilde{\epsilon}_{t}$.
# 幸运的是，我们仍然可以执行二分搜索来获得$\widetilde{\epsilon}_{t}$。
#
# ## CROWN for ReLU, tanh, sigmoid and arctan activations<br />CROWN用于ReLU，tanh，sigmoid和arctan
#
# $$
# S^{+} = \{ r\in[n_{k}] \vert 0 ≤ l^{(k)}_{r} ≤ u^{(k)}_{r} \} \\
# S^{±} = \{ r\in[n_{k}] \vert l^{(k)}_{r} < 0 < u^{(k)}_{r} \} \\
# S^{-} = \{ r\in[n_{k}] \vert l^{(k)}_{r} ≤ u^{(k)}_{r} ≤ 0 \}
# $$
#
# ![5.png](attachment:5.png)
#
# ![6.png](attachment:6.png)
#
# ![7.png](attachment:7.png)
#
# ## Extension to quadratic bounds<br />扩展到二次界
# $$
# h^{(k)}_{U,r}(y) = η^{(k)}_{U,r}y^{2} + α^{(k)}_{U,r}(y + β^{(k)}_{U,r}) \\
# h^{(k)}_{L,r}(y) = η^{(k)}_{L,r}y^{2} + α^{(k)}_{L,r}(y + β^{(k)}_{L,r})
# $$
#
# ![2-2.png](attachment:2-2.png)
#
# ![3-2.png](attachment:3-2.png)
#
# ![7-2.png](attachment:7-2.png)
#
# ![4-2.png](attachment:4-2.png)
#
# ![5-2.png](attachment:5-2.png)
#
# ![6-2.png](attachment:6-2.png)
#
# ![1.png](attachment:1.png)
