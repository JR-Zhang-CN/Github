# %% [markdown]
# # [Towards Stable and Efficient Training of Verifiably Robust Neural Networks<br />稳定高效的可验证鲁棒神经网络的训练](http://arxiv.org/abs/1906.06316)

# %% [markdown]
# CROWN-IBP combines the fast IBP bounds in a forward bounding pass and a tight linear relaxation based bound, CROWN, in a backward bounding pass.
# CROWN-IBP在前向绑定传递中结合了快速IBP边界和在后向绑定传递中基于紧线性松弛的边界CROWN。

# %% [markdown]
# # Verification Specifications<br />验证的规范
#
# ![1.png](attachment:1.png)
#
# Each element in vector $m := Cf (x) \in \mathbb{R}^{n_{L}}$ gives us margins between class $y$ and all other classes.
# 向量$m := Cf (x) \in \mathbb{R}^{n_{L}}$中的每个元素都给出了类$y$和所有其他类之间的边界。
#
# We define the lower bound of $m$ for all $x \in S(x_{k}, \epsilon)$ as $\underline{m}(x_{k}, \epsilon)$.When all elements of $\underline{m}(x_{k}, \epsilon)$ > 0, $x_{k}$ is verifiably robust for any perturbation with $l_{∞}$ norm less than $\epsilon$.
# 我们将所有$x \in S(x_{k}, \epsilon)$的$m$的下界定义为$\underline{m}(x_{k}, \epsilon)$。当$\underline{m}(x_{k}, \epsilon)$的所有元素都大于0时，$x_{k}$对于任何$l_{∞}$范数小于$\epsilon$的扰动都是可验证的鲁棒的。
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # THE PROPOSED ALGORITHM: CROWN-IBP<br />提出的算法：CROWN-IBP
#
# ![image.png](attachment:image.png)
#
# **Forward Bound Propagation in CROWN-IBP<br />CROWN-IBP 中的前向边界传播**
#
# We first obtain $\bar{z}^{(l)}$ and $\underline{z}^{(l)}$.
# 我们首先获得$\bar{z}^{(l)}$和$\underline{z}^{(l)}$。
#
# **Linear Relaxation of ReLU neurons<br />ReLU 神经元的线性松弛**
#
# ![image-2.png](attachment:image-2.png)
#
# We select $α_{k} = 1$ when $\bar{z}^{(l)}_{k} > |\underline{z}^{(l)}_{k}|$ and 0 otherwise.
# 当$\bar{z}^{(l)}_{k} > |\underline{z}^{(l)}_{k}|$时，我们选择$α_{k} = 1$，否则为0。
#
# ![image-3.png](attachment:image-3.png)
#
# **Backward Bound Propagation in CROWN-IBP<br />CROWN-IBP 中的后向边界传播**
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
