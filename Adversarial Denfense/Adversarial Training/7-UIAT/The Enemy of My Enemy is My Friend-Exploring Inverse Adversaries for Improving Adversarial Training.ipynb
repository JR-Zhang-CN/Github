# %% [markdown]
# # [The Enemy of My Enemy is My Friend: Exploring Inverse Adversaries for Improving Adversarial Training<br />敌人的敌人是我的朋友：探索逆对抗以提高对抗训练](https://ieeexplore.ieee.org/document/10204875/)

# %% [markdown]
# The natural intuition is that: adversarial examples corre- sponding to misclassified natural examples are more likely to be misclassified.
# 自然直觉是：与错误分类的自然样本相对应的对抗样本更容易被错误分类。
#
# Several efforts mainly concentrate on mitigating the imbalance of disturbance effect among adversarial examples, while our primary focus is to alleviate the harmful alignment between misclassified examples by incorporating inverse adversarial examples.
# 一些努力主要集中在减轻对抗样本之间扰动效应的不平衡，而我们的主要重点是通过**结合逆对抗样本来减轻错误分类样本之间的有害对齐**。
#
# We investigate the rectification effect of inverse adversarial examples on the distribution alignment during adversarial training for robustness enhancement.
# 我们研究了逆对抗样本在对抗训练期间对分布对齐的矫正效果，以提高鲁棒性。
#
# We built on class-specific universal inverse adversaries for adversarial training with more efficiency and robustness.
# 我们建立了类特定的通用逆对抗方法，用于更有效和更鲁棒的对抗训练。
#
# We show how our method can be combined with single-step adversarial training techniques to improve both the natural performance and robustness.
# 我们展示了如何将我们的方法与单步对抗训练技术相结合，以提高自然性能和鲁棒性。
#
# The robust overfitting comes from the large-loss data during adversarial training. However, our UIAT method implicitly regularizes the large-loss data, a.k.a., misclassified examples to obtain the high-likelihood region of their true classes, which can thus mitigate the robust overfitting problem.
# 鲁棒过拟合来自对抗训练期间的大损失样本。然而，我们的UIAT方法隐式地规范了大损失样本，即错误分类的样本，以获得其真实类别的高可能性区域，从而可以减轻鲁棒过拟合问题。

# %% [markdown]
# ## Inverse Adversarial Examples<br />逆对抗样本
#
# We denote the input feature representation of the last fully-connected layer as $F_{θ}(x)$, adversarial examples as $\hat{x}$ and inverse adversarial examples as $\check{x}$.
# 我们将输入的最后一个全连接层的logits表示为$F_{θ}(x)$，对抗样本为$\hat{x}$，逆对抗样本为$\check{x}$。
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ## Class-specific Inverse Adversaries<br />类特定的逆对抗过程
#
# The universal strategy allows examples of the same class to share a universal adversarial perturbation. In this way, we can find a shared direction to reach high-likelihood regions, which can also mitigate the individual noise between different examples. The class-specific universal adversarial perturbation $z_{c}$ for class c can be defined as:
# 通用策略允许同一类的样本共享通用对抗扰动。通过这种方式，我们可以找到一个共享的方向，以达到高可能性区域，这也可以减轻不同样本之间的个体噪声。类特定的通用对抗扰动$z_{c}$可以定义为：
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# For time efficiency, we only conduct a single-step PGD to update the universal inverse perturbation for a certain category
# 为了提高时间效率，我们只进行单步PGD来更新某一类别的通用逆扰动
#
# ## Universal Inverse Adversarial Training<br />通用逆对抗训练
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
