# %% [markdown]
# # [On the Effectiveness of Interval Bound Propagation for Training Verifiably Robust Models<br />论区间边界传播对训练可验证的鲁棒性模型的有效性](http://arxiv.org/abs/1810.12715)

# %% [markdown]
# IBP allows to define a loss to minimize an upper bound on the maximum difference between any pair of logits when the input can be perturbed within an $l_{∞}$ norm-bounded ball.
# IBP 定义一个损失，当输入可以在一个$l_{∞}$范数约束球内扰动时，最小化任意一对logits之间最大差值的上限。

# %% [markdown]
# ## IBP
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ## For the affine layers<br />对于仿射层
#
# $h_{k}(z_{k-1}) = Wz_{k-1} +b$
#
# ![image-4.png](attachment:image-4.png)
#
# $|·|$ is the element-wise absolute value operator.
# $|·|$是逐元素绝对值运算符。
#
# ## For monotonic activation function<br />对于单调激活函数
# if $h_{k}$ is an element-wise increasing function
# 如果$h_{k}$是逐元素递增函数
#
# ![image-5.png](attachment:image-5.png)
#
# ## LOSS
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
